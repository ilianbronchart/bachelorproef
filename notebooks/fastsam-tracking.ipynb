# %%
# %cd ..
# Out:
# /home/zilian/projects/bachelorproef
# /home/zilian/projects/bachelorproef/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from ultralytics import FastSAM

# %%
model = FastSAM('checkpoints/FastSAM-x.pt')

# %%
results = model.track(source='data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4', imgsz=1080, save=True, show=True)
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 29.7 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 1.5s, installed 1 package: ['lap>=0.5.12']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# WARNING ⚠️ imgsz=[1080] must be multiple of max stride 32, updating to [1088]
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
# ...
