# %%
# %cd ../..
# Out:
# /home/zilian/projects/bachelorproef
# /home/zilian/projects/bachelorproef/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from pathlib import Path
import numpy as np
from src.db import engine
from sqlalchemy.orm import Session
from src.db.models import Recording, SimRoomClass
import matplotlib.pyplot as plt
from src.utils import extract_frames_to_dir
import src.api.jobs.generate_embeddings as generate_embeddings 
import time
# Out:
# 2025-03-18 00:22:37.708666: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-18 00:22:37.715977: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742253757.724485   89245 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742253757.727024   89245 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-18 00:22:37.736529: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
with Session(engine) as session:
    recording = Recording.get("39f5164f-873d-4d6b-be6b-e1d5db79c02a")
    if recording is None:
        raise ValueError("Recording not found")

    video_path = recording.video_path
    gaze_data_path = recording.gaze_data_path
    
class_id_to_name = SimRoomClass.get_id_to_name_map()

# %%
import concurrent.futures
import os
import shutil
import tempfile
import time
from pathlib import Path

import cv2
import numpy as np
import torch
import torchvision.transforms.functional as F
from src.config import GAZE_FOVEA_FOV, TOBII_FOV_X
from src.logic.glasses.gaze import (
    get_gaze_points,
    match_frames_to_gaze,
    parse_gazedata_file,
)
from src.utils import cv2_video_fps, cv2_video_resolution, cv2_video_frame_count
from torchvision.ops import masks_to_boxes
from tqdm import tqdm
from ultralytics import FastSAM
from ultralytics.engine.results import Results
from torchvision.transforms import InterpolationMode
import traceback
from src.aliases import UInt8Array


class GazeSegmentationJob:
    def __init__(
        self,
        video_path: Path,
        gaze_data_path: Path,
        results_path: Path,
        batch_size: int = 50,
        fovea_fov: float = GAZE_FOVEA_FOV,
        fov_x: float = TOBII_FOV_X,
        checkpoint_path: str = "checkpoints/FastSAM-x.pt",
        output_video_path: Path | None = None
    ):
        self.video_path = video_path
        self.gaze_data_path = gaze_data_path
        self.batch_size = batch_size
        self.fovea_fov = fovea_fov
        self.fov_x = fov_x

        # Set up the results directory.
        self.results_path = results_path
        if self.results_path.exists():
            shutil.rmtree(self.results_path, ignore_errors=True)
            self.results_path.mkdir(parents=True, exist_ok=True)
        self.results_path.mkdir(parents=True, exist_ok=True)

        # Load the FastSAM model.
        self.model = FastSAM(checkpoint_path)

        # Video properties.
        self.resolution = cv2_video_resolution(self.video_path)
        self.aspect_ratio = self.resolution[1] / self.resolution[0] # W / H
        self.fps = cv2_video_fps(self.video_path)
        self.viewed_radius = int((self.fovea_fov / self.fov_x) * self.resolution[1])
        self.frame_count = cv2_video_frame_count(self.video_path)

        # Set up the output video.
        if output_video_path is not None:
            self.video_result = cv2.VideoWriter(
                str(output_video_path),
                cv2.VideoWriter_fourcc(*"mp4v"),
                self.fps,
                (self.resolution[1], self.resolution[0]),
            )
        else:
            self.video_result = None
                

        # Parse gaze data.
        self.gaze_data = parse_gazedata_file(self.gaze_data_path)
        self.gaze_points = get_gaze_points(self.gaze_data, self.resolution)

        # Map frame indexes to gaze points.
        self.frame_gaze_mapping = match_frames_to_gaze(
            self.frame_count, self.gaze_points, self.fps
        )

    def get_gaze_position(self, frame_idx: int) -> tuple[int, int] | None:
        """
        Get the gaze position for a frame index.
        """
        gaze_points = self.frame_gaze_mapping[frame_idx]
        if len(gaze_points) == 0:
            return None
        return gaze_points[0].position

    def filter_large_masks(self, masks: torch.Tensor) -> torch.Tensor:
        """
        Filter out masks with area greater than 30% of the frame area

        Args:
            masks: tensor containing masks of shape (N, H, W)
        """
        if len(masks) == 0:
            return masks

        _, height, width = masks.shape
        frame_area = height * width
        max_mask_area = 0.3 * frame_area

        mask_areas = masks.sum(dim=(1, 2))
        filtered_masks = masks[mask_areas <= max_mask_area]
        return filtered_masks

    def filter_viewed_masks(self, masks: torch.Tensor, gaze_position: tuple[float, float]) -> torch.Tensor:
        """
        Filter out masks that are not within the viewed radius of the gaze point.
        Masks should be resized to the size of the original frame before calling this function.

        Args:
            masks: tensor containing masks of shape (N, H, W)
            gaze_position: tuple containing the gaze position (x, y)
        """
        if len(masks) == 0:
            return masks

        sample_mask = masks[0]
        height, width = sample_mask.shape
        device = sample_mask.device

        # Create a circular mask centered at the gaze point.
        y = torch.arange(0, height, device=device).view(-1, 1).repeat(1, width)
        x = torch.arange(0, width, device=device).view(1, -1).repeat(height, 1)
        dist_sq = (x - gaze_position[0]) ** 2 + (y - gaze_position[1]) ** 2
        circular_mask = (
            (dist_sq <= self.viewed_radius**2).float().unsqueeze(0)
        )  # (1, H, W)

        # Apply the circular mask.
        masked_masks = masks * circular_mask
        mask_areas = masked_masks.sum(dim=(1, 2))
        return masks[mask_areas > 0]

    def run(self):
        for frame_idx, results in enumerate(self.model.track(source=str(self.video_path), imgsz=1056, stream=True)):
            continue
            # try:
            #     gaze_position = self.get_gaze_position(frame_idx)
            #     frame = results[0].orig_img

            #     if gaze_position is None:
            #         if self.video_result is not None:
            #             self.write_video_result(frame)
            #         continue
                
            #     masks = torch.stack([result.masks.data[0] for result in results])
            #     masks = F.resize(masks.data, self.resolution, interpolation=InterpolationMode.NEAREST)
            #     filtered_masks = self.filter_large_masks(masks)
            #     viewed_masks = self.filter_viewed_masks(filtered_masks, gaze_position)

            #     boxes = masks_to_boxes(viewed_masks).int().cpu().numpy()

            #     # Extract regions of interest (ROI) for each bounding box.
            #     rois = np.empty(len(boxes), dtype=object)
            #     for i, box in enumerate(boxes):
            #         x1, y1, x2, y2 = box
            #         roi = frame[y1:y2, x1:x2, :]
            #         rois[i] = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)

            #     if self.video_result is not None:
            #         self.write_video_result(frame, viewed_masks, boxes, gaze_position)

            #     np.savez_compressed(
            #         self.results_path / f"{frame_idx}.npz",
            #         boxes=boxes,
            #         rois=rois,
            #     )

            #     # After saving or processing the frame:
            #     # del masks, filtered_masks, viewed_masks, boxes, frame
            #     # del results  # if no longer needed
            #     torch.cuda.empty_cache()
            # except Exception as e:
            #     print(f"Error processing frame {frame_idx}: {e}")
            #     traceback.print_exc()  

        if self.video_result is not None:
            self.video_result.release()

        
    
    def write_video_result(
        self, 
        frame: UInt8Array, 
        masks: torch.Tensor | None = None,
        boxes: torch.Tensor | None = None,
        gaze_position: tuple[int, int] | None = None
    ):
        """
        Write the frame to the output video with the masks and bounding boxes overlayed.
        """
        if masks is not None:
            masks = masks.cpu().numpy()
            masks = (masks * 255).astype(np.uint8)

            for mask in masks:
                mask = cv2.cvtColor(mask.squeeze(), cv2.COLOR_GRAY2BGR)
                frame = cv2.addWeighted(frame, 1, mask, 0.1, 0)

        if boxes is not None:
            for box in boxes:
                x1, y1, x2, y2 = box
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

        if gaze_position is not None:
            cv2.circle(frame, gaze_position, 10, (255, 0, 0), -1)

        self.video_result.write(frame)

# %%
RESULTS_PATH = Path("notebooks/analysis-pipeline/data/fastsam_gaze_segmentation_results")
RESULTS_PATH.mkdir(exist_ok=True)

# if len(list(RESULTS_PATH.iterdir())) == 0:
gaze_sam_job = GazeSegmentationJob(
    video_path=video_path,
    gaze_data_path=gaze_data_path,
    results_path=RESULTS_PATH,
)

gaze_sam_job.run()

# RESULT_VIDEO_PATH = Path("notebooks/analysis-pipeline/data/gaze_output.mp4")
# if not RESULT_VIDEO_PATH.exists():
#     gaze_sam_job.create_video_from_results(RESULT_VIDEO_PATH)
# Out:
# video 1/1 (frame 1/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 135 objects, 41.4ms
# video 1/1 (frame 2/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 134 objects, 15.8ms
# video 1/1 (frame 3/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 137 objects, 15.3ms
# video 1/1 (frame 4/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 138 objects, 15.4ms
# video 1/1 (frame 5/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 141 objects, 15.6ms
# video 1/1 (frame 6/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 142 objects, 15.2ms
# video 1/1 (frame 7/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 142 objects, 14.8ms
# video 1/1 (frame 8/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 141 objects, 14.4ms
# video 1/1 (frame 9/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 143 objects, 21.4ms
# video 1/1 (frame 10/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 143 objects, 14.8ms
# video 1/1 (frame 11/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 146 objects, 14.5ms
# video 1/1 (frame 12/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 145 objects, 14.6ms
# video 1/1 (frame 13/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 140 objects, 14.2ms
# video 1/1 (frame 14/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 136 objects, 14.9ms
# video 1/1 (frame 15/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 139 objects, 14.6ms
# video 1/1 (frame 16/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 141 objects, 14.3ms
# video 1/1 (frame 17/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 109 objects, 14.7ms
# video 1/1 (frame 18/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 97 objects, 14.2ms
# video 1/1 (frame 19/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 14.8ms
# video 1/1 (frame 20/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 46 objects, 14.2ms
# video 1/1 (frame 21/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 38 objects, 14.4ms
# video 1/1 (frame 22/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 27 objects, 22.3ms
# video 1/1 (frame 23/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 15 objects, 14.5ms
# video 1/1 (frame 24/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 7 objects, 14.7ms
# video 1/1 (frame 25/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 8 objects, 21.2ms
# video 1/1 (frame 26/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 10 objects, 14.7ms
# video 1/1 (frame 27/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 8 objects, 14.6ms
# video 1/1 (frame 28/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 10 objects, 14.3ms
# video 1/1 (frame 29/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 13 objects, 14.5ms
# video 1/1 (frame 30/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 10 objects, 14.5ms
# video 1/1 (frame 31/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 12 objects, 17.4ms
# video 1/1 (frame 32/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 15 objects, 14.6ms
# video 1/1 (frame 33/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 18 objects, 14.8ms
# video 1/1 (frame 34/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 19 objects, 14.7ms
# video 1/1 (frame 35/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 21 objects, 20.4ms
# video 1/1 (frame 36/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 25 objects, 14.4ms
# video 1/1 (frame 37/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 30 objects, 14.6ms
# video 1/1 (frame 38/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 39 objects, 15.1ms
# video 1/1 (frame 39/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 46 objects, 14.8ms
# video 1/1 (frame 40/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 48 objects, 14.3ms
# video 1/1 (frame 41/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 51 objects, 16.7ms
# video 1/1 (frame 42/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 56 objects, 19.5ms
# video 1/1 (frame 43/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 14.5ms
# video 1/1 (frame 44/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 56 objects, 15.0ms
# video 1/1 (frame 45/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.5ms
# video 1/1 (frame 46/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 20.9ms
# video 1/1 (frame 47/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.8ms
# video 1/1 (frame 48/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 20.8ms
# video 1/1 (frame 49/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 15.9ms
# video 1/1 (frame 50/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 14.4ms
# video 1/1 (frame 51/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 14.6ms
# video 1/1 (frame 52/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 72 objects, 14.8ms
# video 1/1 (frame 53/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 72 objects, 14.7ms
# video 1/1 (frame 54/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 20.8ms
# video 1/1 (frame 55/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 16.3ms
# video 1/1 (frame 56/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 14.8ms
# video 1/1 (frame 57/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.8ms
# video 1/1 (frame 58/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.8ms
# video 1/1 (frame 59/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.4ms
# video 1/1 (frame 60/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 15.1ms
# video 1/1 (frame 61/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 20.2ms
# video 1/1 (frame 62/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 16.7ms
# video 1/1 (frame 63/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.6ms
# video 1/1 (frame 64/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.5ms
# video 1/1 (frame 65/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 16.2ms
# video 1/1 (frame 66/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 75 objects, 15.2ms
# video 1/1 (frame 67/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 74 objects, 14.6ms
# video 1/1 (frame 68/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 73 objects, 21.4ms
# video 1/1 (frame 69/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 72 objects, 15.0ms
# video 1/1 (frame 70/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 16.8ms
# video 1/1 (frame 71/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 20.8ms
# video 1/1 (frame 72/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.6ms
# video 1/1 (frame 73/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 21.0ms
# video 1/1 (frame 74/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.9ms
# video 1/1 (frame 75/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 20.4ms
# video 1/1 (frame 76/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 16.1ms
# video 1/1 (frame 77/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.6ms
# video 1/1 (frame 78/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.6ms
# video 1/1 (frame 79/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 15.0ms
# video 1/1 (frame 80/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.8ms
# video 1/1 (frame 81/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 15.2ms
# video 1/1 (frame 82/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.6ms
# video 1/1 (frame 83/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.8ms
# video 1/1 (frame 84/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.8ms
# video 1/1 (frame 85/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 17.1ms
# video 1/1 (frame 86/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 17.0ms
# video 1/1 (frame 87/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.7ms
# video 1/1 (frame 88/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 15.1ms
# video 1/1 (frame 89/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 15.5ms
# video 1/1 (frame 90/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.3ms
# video 1/1 (frame 91/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.5ms
# video 1/1 (frame 92/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.7ms
# video 1/1 (frame 93/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 14.5ms
# video 1/1 (frame 94/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 14.5ms
# video 1/1 (frame 95/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.8ms
# video 1/1 (frame 96/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.7ms
# video 1/1 (frame 97/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.7ms
# video 1/1 (frame 98/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.3ms
# video 1/1 (frame 99/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.6ms
# video 1/1 (frame 100/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 15.0ms
# video 1/1 (frame 101/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 14.9ms
# video 1/1 (frame 102/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.9ms
# video 1/1 (frame 103/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.5ms
# video 1/1 (frame 104/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.6ms
# video 1/1 (frame 105/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 14.8ms
# video 1/1 (frame 106/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.9ms
# video 1/1 (frame 107/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 16.6ms
# video 1/1 (frame 108/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 14.6ms
# video 1/1 (frame 109/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 72 objects, 21.3ms
# video 1/1 (frame 110/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 14.4ms
# video 1/1 (frame 111/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 72 objects, 14.8ms
# video 1/1 (frame 112/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 16.0ms
# video 1/1 (frame 113/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.6ms
# video 1/1 (frame 114/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.5ms
# video 1/1 (frame 115/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.7ms
# video 1/1 (frame 116/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.6ms
# video 1/1 (frame 117/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.5ms
# video 1/1 (frame 118/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 15.0ms
# video 1/1 (frame 119/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.8ms
# video 1/1 (frame 120/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 16.5ms
# video 1/1 (frame 121/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 14.6ms
# video 1/1 (frame 122/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.8ms
# video 1/1 (frame 123/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.3ms
# video 1/1 (frame 124/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 14.6ms
# video 1/1 (frame 125/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 55 objects, 15.3ms
# video 1/1 (frame 126/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 15.1ms
# video 1/1 (frame 127/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.7ms
# video 1/1 (frame 128/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.2ms
# video 1/1 (frame 129/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 15.0ms
# video 1/1 (frame 130/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.7ms
# video 1/1 (frame 131/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.6ms
# video 1/1 (frame 132/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 17.1ms
# video 1/1 (frame 133/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 14.8ms
# video 1/1 (frame 134/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.8ms
# video 1/1 (frame 135/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 14.9ms
# video 1/1 (frame 136/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 15.6ms
# video 1/1 (frame 137/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 14.8ms
# video 1/1 (frame 138/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 16.4ms
# video 1/1 (frame 139/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.8ms
# video 1/1 (frame 140/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.3ms
# video 1/1 (frame 141/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.6ms
# video 1/1 (frame 142/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.8ms
# video 1/1 (frame 143/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 16.7ms
# video 1/1 (frame 144/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.5ms
# video 1/1 (frame 145/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.6ms
# video 1/1 (frame 146/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 14.8ms
# video 1/1 (frame 147/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 15.0ms
# video 1/1 (frame 148/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 14.3ms
# video 1/1 (frame 149/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.9ms
# video 1/1 (frame 150/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 15.0ms
# video 1/1 (frame 151/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.5ms
# video 1/1 (frame 152/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.8ms
# video 1/1 (frame 153/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 14.9ms
# video 1/1 (frame 154/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.6ms
# video 1/1 (frame 155/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.4ms
# video 1/1 (frame 156/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 17.0ms
# video 1/1 (frame 157/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 72 objects, 14.7ms
# video 1/1 (frame 158/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 75 objects, 14.6ms
# video 1/1 (frame 159/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 75 objects, 14.6ms
# video 1/1 (frame 160/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 77 objects, 15.4ms
# video 1/1 (frame 161/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 77 objects, 14.2ms
# video 1/1 (frame 162/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 77 objects, 14.4ms
# video 1/1 (frame 163/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 77 objects, 14.6ms
# video 1/1 (frame 164/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 83 objects, 14.6ms
# video 1/1 (frame 165/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 83 objects, 14.7ms
# video 1/1 (frame 166/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 85 objects, 15.0ms
# video 1/1 (frame 167/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 83 objects, 15.0ms
# video 1/1 (frame 168/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 80 objects, 14.7ms
# video 1/1 (frame 169/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 79 objects, 16.0ms
# video 1/1 (frame 170/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 82 objects, 14.7ms
# video 1/1 (frame 171/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 84 objects, 14.5ms
# video 1/1 (frame 172/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 84 objects, 14.4ms
# video 1/1 (frame 173/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 83 objects, 16.8ms
# video 1/1 (frame 174/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 81 objects, 14.8ms
# video 1/1 (frame 175/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 79 objects, 14.6ms
# video 1/1 (frame 176/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 78 objects, 16.7ms
# video 1/1 (frame 177/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 74 objects, 16.3ms
# video 1/1 (frame 178/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 74 objects, 15.7ms
# video 1/1 (frame 179/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 75 objects, 14.9ms
# video 1/1 (frame 180/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 77 objects, 14.9ms
# video 1/1 (frame 181/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 77 objects, 14.6ms
# video 1/1 (frame 182/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 74 objects, 14.8ms
# video 1/1 (frame 183/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 72 objects, 14.9ms
# video 1/1 (frame 184/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.8ms
# video 1/1 (frame 185/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.4ms
# video 1/1 (frame 186/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 14.8ms
# video 1/1 (frame 187/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.7ms
# video 1/1 (frame 188/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 16.7ms
# video 1/1 (frame 189/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 19.1ms
# video 1/1 (frame 190/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 14.6ms
# video 1/1 (frame 191/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 14.4ms
# video 1/1 (frame 192/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.9ms
# video 1/1 (frame 193/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.6ms
# video 1/1 (frame 194/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.6ms
# video 1/1 (frame 195/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.9ms
# video 1/1 (frame 196/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.9ms
# video 1/1 (frame 197/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.9ms
# video 1/1 (frame 198/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.5ms
# video 1/1 (frame 199/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.6ms
# video 1/1 (frame 200/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 14.7ms
# video 1/1 (frame 201/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 21.0ms
# video 1/1 (frame 202/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.9ms
# video 1/1 (frame 203/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.9ms
# video 1/1 (frame 204/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.4ms
# video 1/1 (frame 205/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.9ms
# video 1/1 (frame 206/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 15.1ms
# video 1/1 (frame 207/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 16.2ms
# video 1/1 (frame 208/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 14.3ms
# video 1/1 (frame 209/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.5ms
# video 1/1 (frame 210/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 21.8ms
# video 1/1 (frame 211/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.5ms
# video 1/1 (frame 212/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.8ms
# video 1/1 (frame 213/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 14.9ms
# video 1/1 (frame 214/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 16.8ms
# video 1/1 (frame 215/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 17.6ms
# video 1/1 (frame 216/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 20.8ms
# video 1/1 (frame 217/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 14.1ms
# video 1/1 (frame 218/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.8ms
# video 1/1 (frame 219/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 14.6ms
# video 1/1 (frame 220/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 72 objects, 14.1ms
# video 1/1 (frame 221/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 14.6ms
# video 1/1 (frame 222/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 70 objects, 15.0ms
# video 1/1 (frame 223/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.8ms
# video 1/1 (frame 224/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 21.6ms
# video 1/1 (frame 225/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.7ms
# video 1/1 (frame 226/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.7ms
# video 1/1 (frame 227/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 21.6ms
# video 1/1 (frame 228/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 21.1ms
# video 1/1 (frame 229/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 15.3ms
# video 1/1 (frame 230/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 15.4ms
# video 1/1 (frame 231/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.5ms
# video 1/1 (frame 232/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 56 objects, 14.4ms
# video 1/1 (frame 233/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 45 objects, 14.7ms
# video 1/1 (frame 234/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 32 objects, 14.6ms
# video 1/1 (frame 235/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 30 objects, 14.5ms
# video 1/1 (frame 236/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 21 objects, 15.0ms
# video 1/1 (frame 237/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 18 objects, 14.9ms
# video 1/1 (frame 238/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 13 objects, 14.7ms
# video 1/1 (frame 239/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 13 objects, 14.6ms
# video 1/1 (frame 240/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 12 objects, 14.6ms
# video 1/1 (frame 241/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 11 objects, 14.6ms
# video 1/1 (frame 242/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 15 objects, 14.5ms
# video 1/1 (frame 243/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 22 objects, 14.8ms
# video 1/1 (frame 244/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 29 objects, 15.0ms
# video 1/1 (frame 245/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 31 objects, 21.6ms
# video 1/1 (frame 246/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 39 objects, 14.8ms
# video 1/1 (frame 247/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 49 objects, 14.9ms
# video 1/1 (frame 248/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 53 objects, 15.1ms
# video 1/1 (frame 249/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 14.9ms
# video 1/1 (frame 250/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.9ms
# video 1/1 (frame 251/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 71 objects, 14.5ms
# video 1/1 (frame 252/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 75 objects, 19.3ms
# video 1/1 (frame 253/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 74 objects, 15.1ms
# video 1/1 (frame 254/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 14.9ms
# video 1/1 (frame 255/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 14.6ms
# video 1/1 (frame 256/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 40 objects, 15.4ms
# video 1/1 (frame 257/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 25 objects, 14.9ms
# video 1/1 (frame 258/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 16 objects, 20.4ms
# video 1/1 (frame 259/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 11 objects, 15.8ms
# video 1/1 (frame 260/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 7 objects, 14.4ms
# video 1/1 (frame 261/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 9 objects, 20.6ms
# video 1/1 (frame 262/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 8 objects, 20.4ms
# video 1/1 (frame 263/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 6 objects, 14.9ms
# video 1/1 (frame 264/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 9 objects, 21.3ms
# video 1/1 (frame 265/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 21 objects, 14.2ms
# video 1/1 (frame 266/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 26 objects, 14.6ms
# video 1/1 (frame 267/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 39 objects, 15.0ms
# video 1/1 (frame 268/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 47 objects, 14.7ms
# video 1/1 (frame 269/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 53 objects, 14.4ms
# video 1/1 (frame 270/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 54 objects, 14.7ms
# video 1/1 (frame 271/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 57 objects, 14.4ms
# video 1/1 (frame 272/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 59 objects, 14.7ms
# video 1/1 (frame 273/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 14.7ms
# video 1/1 (frame 274/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.4ms
# video 1/1 (frame 275/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.5ms
# video 1/1 (frame 276/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 15.0ms
# video 1/1 (frame 277/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.5ms
# video 1/1 (frame 278/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.4ms
# video 1/1 (frame 279/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 21.2ms
# video 1/1 (frame 280/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 20.8ms
# video 1/1 (frame 281/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 15.1ms
# video 1/1 (frame 282/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.2ms
# video 1/1 (frame 283/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 14.6ms
# video 1/1 (frame 284/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 59 objects, 14.8ms
# video 1/1 (frame 285/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 59 objects, 15.1ms
# video 1/1 (frame 286/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 14.6ms
# video 1/1 (frame 287/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 14.5ms
# video 1/1 (frame 288/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 14.9ms
# video 1/1 (frame 289/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 14.8ms
# video 1/1 (frame 290/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 60 objects, 14.6ms
# video 1/1 (frame 291/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 16.4ms
# video 1/1 (frame 292/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 15.0ms
# video 1/1 (frame 293/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 15.0ms
# video 1/1 (frame 294/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 18.8ms
# video 1/1 (frame 295/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.4ms
# video 1/1 (frame 296/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.7ms
# video 1/1 (frame 297/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 14.8ms
# video 1/1 (frame 298/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 59 objects, 14.5ms
# video 1/1 (frame 299/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 59 objects, 14.3ms
# video 1/1 (frame 300/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.5ms
# video 1/1 (frame 301/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 16.1ms
# video 1/1 (frame 302/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.7ms
# video 1/1 (frame 303/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.3ms
# video 1/1 (frame 304/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 14.4ms
# video 1/1 (frame 305/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 61 objects, 14.9ms
# video 1/1 (frame 306/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 63 objects, 16.7ms
# video 1/1 (frame 307/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 62 objects, 14.3ms
# video 1/1 (frame 308/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.9ms
# video 1/1 (frame 309/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 15.0ms
# video 1/1 (frame 310/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.5ms
# video 1/1 (frame 311/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.8ms
# video 1/1 (frame 312/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.9ms
# video 1/1 (frame 313/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 65 objects, 14.4ms
# video 1/1 (frame 314/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 64 objects, 14.2ms
# video 1/1 (frame 315/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 15.6ms
# video 1/1 (frame 316/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.2ms
# video 1/1 (frame 317/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 67 objects, 15.2ms
# video 1/1 (frame 318/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.6ms
# video 1/1 (frame 319/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 69 objects, 14.4ms
# video 1/1 (frame 320/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 66 objects, 14.0ms
# video 1/1 (frame 321/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 55 objects, 15.0ms
# video 1/1 (frame 322/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 49 objects, 14.9ms
# ...
# video 1/1 (frame 2440/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 43 objects, 15.8ms
# video 1/1 (frame 2441/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 46 objects, 15.9ms
# video 1/1 (frame 2442/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 45 objects, 19.3ms
# video 1/1 (frame 2443/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 43 objects, 14.4ms
# video 1/1 (frame 2444/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 41 objects, 14.6ms
# video 1/1 (frame 2445/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 35 objects, 14.6ms
# video 1/1 (frame 2446/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 34 objects, 14.8ms
# video 1/1 (frame 2447/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 33 objects, 15.7ms
# video 1/1 (frame 2448/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 30 objects, 21.6ms
# video 1/1 (frame 2449/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 28 objects, 14.4ms
# video 1/1 (frame 2450/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 28 objects, 20.4ms
# video 1/1 (frame 2451/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 28 objects, 14.4ms
# video 1/1 (frame 2452/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 27 objects, 14.8ms
# video 1/1 (frame 2453/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 26 objects, 14.8ms
# video 1/1 (frame 2454/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 31 objects, 14.4ms
# video 1/1 (frame 2455/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 33 objects, 14.4ms
# video 1/1 (frame 2456/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 31 objects, 20.6ms
# video 1/1 (frame 2457/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 34 objects, 14.8ms
# video 1/1 (frame 2458/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 35 objects, 14.3ms
# video 1/1 (frame 2459/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 43 objects, 20.7ms
# video 1/1 (frame 2460/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 56 objects, 14.3ms
# video 1/1 (frame 2461/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 68 objects, 14.1ms
# video 1/1 (frame 2462/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 75 objects, 20.5ms
# video 1/1 (frame 2463/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 76 objects, 14.4ms
# video 1/1 (frame 2464/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 82 objects, 14.9ms
# video 1/1 (frame 2465/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 90 objects, 14.8ms
# video 1/1 (frame 2466/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 98 objects, 14.5ms
# video 1/1 (frame 2467/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 98 objects, 18.2ms
# video 1/1 (frame 2468/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 98 objects, 14.3ms
# video 1/1 (frame 2469/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 95 objects, 14.8ms
# video 1/1 (frame 2470/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 100 objects, 14.7ms
# video 1/1 (frame 2471/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 97 objects, 22.1ms
# video 1/1 (frame 2472/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 98 objects, 17.0ms
# video 1/1 (frame 2473/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 107 objects, 14.1ms
# video 1/1 (frame 2474/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 114 objects, 14.8ms
# video 1/1 (frame 2475/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 119 objects, 14.5ms
# video 1/1 (frame 2476/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 127 objects, 15.7ms
# video 1/1 (frame 2477/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 130 objects, 14.5ms
# video 1/1 (frame 2478/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 136 objects, 14.7ms
# video 1/1 (frame 2479/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 139 objects, 14.1ms
# video 1/1 (frame 2480/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 143 objects, 14.5ms
# video 1/1 (frame 2481/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 151 objects, 14.4ms
# video 1/1 (frame 2482/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 149 objects, 15.0ms
# video 1/1 (frame 2483/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 150 objects, 14.2ms
# video 1/1 (frame 2484/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 158 objects, 20.8ms
# video 1/1 (frame 2485/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 159 objects, 14.7ms
# video 1/1 (frame 2486/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 159 objects, 16.2ms
# video 1/1 (frame 2487/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 162 objects, 14.6ms
# video 1/1 (frame 2488/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 162 objects, 20.0ms
# video 1/1 (frame 2489/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 161 objects, 14.4ms
# video 1/1 (frame 2490/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 159 objects, 20.1ms
# video 1/1 (frame 2491/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 159 objects, 14.5ms
# video 1/1 (frame 2492/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 156 objects, 14.8ms
# video 1/1 (frame 2493/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 155 objects, 14.3ms
# video 1/1 (frame 2494/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 154 objects, 14.9ms
# video 1/1 (frame 2495/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 152 objects, 14.5ms
# video 1/1 (frame 2496/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 153 objects, 14.4ms
# video 1/1 (frame 2497/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 160 objects, 17.2ms
# video 1/1 (frame 2498/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 163 objects, 14.4ms
# video 1/1 (frame 2499/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 167 objects, 14.5ms
# video 1/1 (frame 2500/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 169 objects, 14.4ms
# video 1/1 (frame 2501/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 170 objects, 14.7ms
# video 1/1 (frame 2502/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 170 objects, 14.7ms
# video 1/1 (frame 2503/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 172 objects, 20.8ms
# video 1/1 (frame 2504/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 172 objects, 14.4ms
# video 1/1 (frame 2505/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 170 objects, 15.0ms
# video 1/1 (frame 2506/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 169 objects, 14.4ms
# video 1/1 (frame 2507/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 170 objects, 20.4ms
# video 1/1 (frame 2508/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 169 objects, 14.7ms
# video 1/1 (frame 2509/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 170 objects, 14.2ms
# video 1/1 (frame 2510/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 170 objects, 14.8ms
# video 1/1 (frame 2511/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 173 objects, 16.6ms
# video 1/1 (frame 2512/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 173 objects, 14.7ms
# video 1/1 (frame 2513/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 170 objects, 14.4ms
# video 1/1 (frame 2514/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 175 objects, 14.4ms
# video 1/1 (frame 2515/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 175 objects, 14.7ms
# video 1/1 (frame 2516/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 171 objects, 14.5ms
# video 1/1 (frame 2517/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 171 objects, 14.7ms
# video 1/1 (frame 2518/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 175 objects, 14.4ms
# video 1/1 (frame 2519/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 175 objects, 14.7ms
# video 1/1 (frame 2520/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 176 objects, 14.4ms
# video 1/1 (frame 2521/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 177 objects, 14.5ms
# video 1/1 (frame 2522/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 176 objects, 17.3ms
# video 1/1 (frame 2523/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 176 objects, 15.0ms
# video 1/1 (frame 2524/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 174 objects, 14.7ms
# video 1/1 (frame 2525/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 175 objects, 14.4ms
# video 1/1 (frame 2526/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 164 objects, 14.6ms
# video 1/1 (frame 2527/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 157 objects, 14.5ms
# video 1/1 (frame 2528/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 159 objects, 14.8ms
# video 1/1 (frame 2529/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 157 objects, 17.5ms
# video 1/1 (frame 2530/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 156 objects, 14.7ms
# video 1/1 (frame 2531/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 156 objects, 15.7ms
# video 1/1 (frame 2532/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 158 objects, 14.4ms
# video 1/1 (frame 2533/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 159 objects, 14.9ms
# video 1/1 (frame 2534/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 158 objects, 14.5ms
# video 1/1 (frame 2535/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 159 objects, 14.6ms
# video 1/1 (frame 2536/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 162 objects, 14.5ms
# video 1/1 (frame 2537/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 162 objects, 15.0ms
# video 1/1 (frame 2538/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 162 objects, 16.6ms
# video 1/1 (frame 2539/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 164 objects, 14.6ms
# video 1/1 (frame 2540/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 165 objects, 14.5ms
# video 1/1 (frame 2541/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 165 objects, 15.4ms
# video 1/1 (frame 2542/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 163 objects, 15.0ms
# video 1/1 (frame 2543/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 162 objects, 20.4ms
# video 1/1 (frame 2544/2544) /home/zilian/projects/bachelorproef/data/recordings/39f5164f-873d-4d6b-be6b-e1d5db79c02a.mp4: 608x1056 164 objects, 14.7ms
# Speed: 2.2ms preprocess, 16.1ms inference, 3.2ms postprocess per image at shape (1, 3, 608, 1056)

# %%
gaze_segmentation_results = list(RESULTS_PATH.iterdir())
gaze_segmentation_results.sort(key=lambda x: int(x.stem))

rois_per_frame = []
boxes_per_frame = []

for result_path in gaze_segmentation_results:
    result = np.load(result_path, allow_pickle=True)
    rois_per_frame.append(result["rois"])
    boxes_per_frame.append(result["boxes"])

# %%
frame_idx = 1300
for i, rois in enumerate(rois_per_frame):
    if i != frame_idx:
        continue
    plt.imshow(rois[0])
    plt.axis("off")
    plt.title(f"Frame {i}")
    plt.show()
    break

# %%
dinov2 = generate_embeddings.load_model()
index = generate_embeddings.read_index(Path("notebooks/analysis-pipeline/data/embeddings.index"))

# %%
import numpy as np
import matplotlib.pyplot as plt

rois = rois_per_frame[frame_idx]
embeddings, _, _ = list(generate_embeddings.get_embeddings(dinov2, rois))[0]
distances, indices = generate_embeddings.search_index(index, embeddings, k=50)

for i, (roi, embedding) in enumerate(zip(rois, embeddings)):
    D, I = distances[i], indices[i]
    # Map class IDs to names
    class_names = [class_id_to_name[idx] for idx in I]
    
    # Group distances by class name
    class_to_distances = {}
    for class_idx, distance in zip(I, D):
        class_name = class_id_to_name[class_idx]
        class_to_distances.setdefault(class_name, []).append(distance)
    
    # Calculate metrics for each class
    avg_distances = {}
    min_distances = {}
    max_distances = {}
    var_distances = {}
    
    for cls, dists in class_to_distances.items():
        avg_distances[cls] = np.mean(dists)
        min_distances[cls] = np.min(dists)
        max_distances[cls] = np.max(dists)
        var_distances[cls] = np.var(dists)

    print(var_distances)
    
    # Determine the top class based on average distance
    sorted_classes = sorted(avg_distances.items(), key=lambda x: x[1])
    
    # Create one figure with two subplots side by side
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))
    
    # Left subplot: Display the ROI with the top class in the title
    ax1.imshow(roi)
    ax1.set_title(f"ROI {i} - Top class: {sorted_classes[0][0]} (avg: {sorted_classes[0][1]:.4f})")
    ax1.axis('off')
    
    # Right subplot: Grouped bar chart for various distance metrics per class
    classes = list(avg_distances.keys())
    x = np.arange(len(classes))
    width = 0.2  # width of each bar
    
    # Extract metric values for each class
    avg_vals = [avg_distances[cls] for cls in classes]
    min_vals = [min_distances[cls] for cls in classes]
    max_vals = [max_distances[cls] for cls in classes]
    var_vals = [var_distances[cls] for cls in classes]
    
    # Create grouped bars
    ax2.bar(x - 1.5 * width, avg_vals, width, label='Avg')
    ax2.bar(x - 0.5 * width, min_vals, width, label='Min')
    ax2.bar(x + 0.5 * width, max_vals, width, label='Max')
    ax2.bar(x + 1.5 * width, var_vals, width, label='Variance')
    
    ax2.set_xticks(x)
    ax2.set_xticklabels(classes, rotation=45)
    ax2.set_xlabel("Class Name")
    ax2.set_ylabel("Distance")
    ax2.set_title(f"ROI {i} - Distance Metrics per Class")
    ax2.legend()
    
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 rois = rois_per_frame[frame_idx]
#       5 embeddings, _, _ = list(generate_embeddings.get_embeddings(dinov2, rois))[0]
#       6 distances, indices = generate_embeddings.search_index(index, embeddings, k=50)
#
# IndexError: list index out of range
